# %% [markdown]
# # Import Libraries

# %%
import pandas as pd # data manipulation librabry
import numpy as np # numerical computation library
import matplotlib.pyplot as plt # data visual library
import itertools # for permutations
import seaborn as sns #needed for heatmap 

# Display up to 120 columns of a dataframe
pd.set_option('display.max_columns', 120)

# %%
match_info = pd.read_csv('Permutations/Data/Match Info.csv')
standings = pd.read_csv('Permutations/Data/Standings.csv')

# %% [markdown]
# ### Get first 5 entries of match info

# %%
match_info.head()
# Out:
#    competition_id  match_id  match_date                    match_name result  \
# 0          288898    143176  2024-10-23               Poland - Brazil    NaN
# 1          288898    143179  2024-10-26                       1C - 2D    NaN
# 2          288898    143155  2024-10-16  Dominican Republic - Ecuador    0-2
# 3          288898    143160  2024-10-16                   Spain - USA    3-1
# 4          288898    143175  2024-10-20               Zambia - Poland    0-2
#
#   fifa_ranking cat_code team_cat                           venue
# 0          yes  FU17WWC      U17                Estadio Cibao FC
# 1          yes  FU17WWC      U17                Estadio Cibao FC
# 2          yes  FU17WWC      U17                Estadio Cibao FC
# 3          yes  FU17WWC      U17  Estadio Olímpico Félix Sánchez
# 4          yes  FU17WWC      U17  Estadio Olímpico Félix Sánchez

# %% [markdown]
# ### Get first 5 entries of standings

# %%
standings.head()
# Out:
#    competition_structure_id competition_structure_name  \
# 0                    288900                    Group A
# 1                    288900                    Group A
# 2                    288900                    Group A
# 3                    288900                    Group A
# 4                    288900                    Group A
#
#            enqueued_time_utc  is_live  is_most_recent qualification_status  \
# 0  2024-10-23 01:02:23.000 Z    False            True           Eliminated
# 1  2024-10-23 01:02:23.000 Z    False            True           Eliminated
# 2  2024-10-23 01:02:23.000 Z    False            True           Eliminated
# 3  2024-10-23 01:02:23.000 Z    False            True           Eliminated
# 4  2024-10-23 01:02:23.000 Z    False            True           Eliminated
#
#    ranking   statistic_type  team_id team_name_short  value  \
# 0        4     GoalsAgainst  1915093     New Zealand      9
# 1        4  GoalsDifference  1915093     New Zealand     -7
# 2        4         GoalsFor  1915093     New Zealand      2
# 3        4     MatchesDrawn  1915093     New Zealand      1
# 4        4      MatchesLost  1915093     New Zealand      2
#
#          fdh_inserttimestamp        fdh_updatetimestamp  fdh_deletetimestamp  \
# 0  2024-10-17 03:19:42.866 Z  2024-10-23 03:17:22.470 Z                  NaN
# 1  2024-10-17 03:19:42.866 Z  2024-10-23 03:17:22.470 Z                  NaN
# 2  2024-10-17 03:19:42.866 Z  2024-10-23 03:17:22.470 Z                  NaN
# 3  2024-10-17 03:19:42.866 Z  2024-10-23 03:17:22.470 Z                  NaN
# 4  2024-10-17 03:19:42.866 Z  2024-10-23 03:17:22.470 Z                  NaN
#
#                  fdh_fullrecordhash
# 0  ba69e4240ad77f3fec03ba74e73b3dbe
# 1  9cf4a5e8fc8f8b516a781be82752114b
# 2  075d3a49e497193a017f95f8165872e8
# 3  b782665780405906caaf8e69a20cca62
# 4  075d3a49e497193a017f95f8165872e8

# %% [markdown]
# ### Filter Group D only

# %%
standings[standings['competition_structure_name'] == 'Group D']
# Out:
#      competition_structure_id competition_structure_name  \
# 108                    288902                    Group D
# 109                    288902                    Group D
# 110                    288902                    Group D
# 111                    288902                    Group D
# 112                    288902                    Group D
# 113                    288902                    Group D
# 114                    288902                    Group D
# 115                    288902                    Group D
# 116                    288902                    Group D
# 117                    288902                    Group D
# 118                    288902                    Group D
# 119                    288902                    Group D
# 120                    288902                    Group D
# 121                    288902                    Group D
# 122                    288902                    Group D
# 123                    288902                    Group D
# 124                    288902                    Group D
# 125                    288902                    Group D
# 126                    288902                    Group D
# 127                    288902                    Group D
# 128                    288902                    Group D
# 129                    288902                    Group D
# 130                    288902                    Group D
# 131                    288902                    Group D
# 132                    288902                    Group D
# 133                    288902                    Group D
# 134                    288902                    Group D
# 135                    288902                    Group D
# 136                    288902                    Group D
# 137                    288902                    Group D
# 138                    288902                    Group D
# 139                    288902                    Group D
# 140                    288902                    Group D
# 141                    288902                    Group D
# 142                    288902                    Group D
# 143                    288902                    Group D
#
#              enqueued_time_utc  is_live  is_most_recent qualification_status  \
# 108  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 109  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 110  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 111  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 112  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 113  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 114  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 115  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 116  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 117  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 118  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 119  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 120  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 121  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 122  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 123  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 124  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 125  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 126  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 127  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 128  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 129  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 130  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 131  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 132  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 133  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 134  2024-10-21 01:01:25.000 Z    False            True         CouldQualify
# 135  2024-10-21 01:01:25.000 Z    False            True           Eliminated
# 136  2024-10-21 01:01:25.000 Z    False            True           Eliminated
# 137  2024-10-21 01:01:25.000 Z    False            True           Eliminated
# 138  2024-10-21 01:01:25.000 Z    False            True           Eliminated
# 139  2024-10-21 01:01:25.000 Z    False            True           Eliminated
# 140  2024-10-21 01:01:25.000 Z    False            True           Eliminated
# 141  2024-10-21 01:01:25.000 Z    False            True           Eliminated
# 142  2024-10-21 01:01:25.000 Z    False            True           Eliminated
# 143  2024-10-21 01:01:25.000 Z    False            True           Eliminated
#
#      ranking    statistic_type  team_id team_name_short  value  \
# 108        2      GoalsAgainst  1914191           Japan      1
# 109        2   GoalsDifference  1914191           Japan      1
# 110        2          GoalsFor  1914191           Japan      2
# 111        2      MatchesDrawn  1914191           Japan      1
# 112        2       MatchesLost  1914191           Japan      0
# 113        2     MatchesPlayed  1914191           Japan      2
# 114        2        MatchesWon  1914191           Japan      1
# 115        2            Points  1914191           Japan      4
# 116        2  TeamConductScore  1914191           Japan     -1
# 117        1      GoalsAgainst  1914796          Poland      0
# 118        1   GoalsDifference  1914796          Poland      2
# 119        1          GoalsFor  1914796          Poland      2
# 120        1      MatchesDrawn  1914796          Poland      1
# 121        1       MatchesLost  1914796          Poland      0
# 122        1     MatchesPlayed  1914796          Poland      2
# 123        1        MatchesWon  1914796          Poland      1
# 124        1            Points  1914796          Poland      4
# 125        1  TeamConductScore  1914796          Poland     -1
# 126        3      GoalsAgainst  1915201          Brazil      2
# 127        3   GoalsDifference  1915201          Brazil      0
# 128        3          GoalsFor  1915201          Brazil      2
# 129        3      MatchesDrawn  1915201          Brazil      0
# 130        3       MatchesLost  1915201          Brazil      1
# 131        3     MatchesPlayed  1915201          Brazil      2
# 132        3        MatchesWon  1915201          Brazil      1
# 133        3            Points  1915201          Brazil      3
# 134        3  TeamConductScore  1915201          Brazil     -4
# 135        4      GoalsAgainst  1915239          Zambia      3
# 136        4   GoalsDifference  1915239          Zambia     -3
# 137        4          GoalsFor  1915239          Zambia      0
# 138        4      MatchesDrawn  1915239          Zambia      0
# 139        4       MatchesLost  1915239          Zambia      2
# 140        4     MatchesPlayed  1915239          Zambia      2
# 141        4        MatchesWon  1915239          Zambia      0
# 142        4            Points  1915239          Zambia      0
# 143        4  TeamConductScore  1915239          Zambia     -2
#
#            fdh_inserttimestamp        fdh_updatetimestamp  \
# 108  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 109  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 110  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 111  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 112  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 113  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 114  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 115  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 116  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 117  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 118  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 119  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 120  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 121  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 122  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 123  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 124  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 125  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 126  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 127  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 128  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 129  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 130  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 131  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 132  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 133  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 134  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 135  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 136  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 137  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 138  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 139  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 140  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 141  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 142  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
# 143  2024-10-18 03:20:42.031 Z  2024-10-21 03:24:59.082 Z
#
#      fdh_deletetimestamp                fdh_fullrecordhash
# 108                  NaN  2d71178d39317333aaa23878c31b7193
# 109                  NaN  2d71178d39317333aaa23878c31b7193
# 110                  NaN  c08ccb66f306cfb01cf730184da2004e
# 111                  NaN  2d71178d39317333aaa23878c31b7193
# 112                  NaN  7333aaabf19e7e32795e90b17a38e8a8
# 113                  NaN  c08ccb66f306cfb01cf730184da2004e
# 114                  NaN  2d71178d39317333aaa23878c31b7193
# 115                  NaN  f29c6668fdd7532edc6e1942e1b28cb2
# 116                  NaN  883541503acdaf7764452d5400c6deaf
# 117                  NaN  3a97104bb0f031cd2939711aa7d56119
# 118                  NaN  4cc82ee82110b8f4630bd36fce44807f
# 119                  NaN  4cc82ee82110b8f4630bd36fce44807f
# 120                  NaN  a21e30a9989a101a94c8b441f3fcc228
# 121                  NaN  3a97104bb0f031cd2939711aa7d56119
# 122                  NaN  4cc82ee82110b8f4630bd36fce44807f
# 123                  NaN  a21e30a9989a101a94c8b441f3fcc228
# 124                  NaN  9205d0c9e8351314e2f92048e2090fef
# 125                  NaN  32f3a7a016f384781696e736c0dbf12b
# 126                  NaN  49e7f2a0852681257c91375b23ccbf83
# 127                  NaN  ff1082d473f9fa56d5bfecb5b4252196
# 128                  NaN  49e7f2a0852681257c91375b23ccbf83
# 129                  NaN  ff1082d473f9fa56d5bfecb5b4252196
# 130                  NaN  274c0ca1c3a10ed534b119d5c1c18674
# 131                  NaN  49e7f2a0852681257c91375b23ccbf83
# 132                  NaN  274c0ca1c3a10ed534b119d5c1c18674
# 133                  NaN  347c94c40e4e80cdd474c85ae53a2205
# 134                  NaN  d30ee6fa6d289af63edc7326f19ccdb6
# 135                  NaN  b97f6a56bd39ce92b33c6ea8e4eb830e
# 136                  NaN  804ad64d8750ac4c429914fb1771b869
# 137                  NaN  862d718e091eca23d264d34dff86d9af
# 138                  NaN  862d718e091eca23d264d34dff86d9af
# 139                  NaN  c3850ff48a4d60d4f7c54b0b66da5934
# 140                  NaN  c3850ff48a4d60d4f7c54b0b66da5934
# 141                  NaN  862d718e091eca23d264d34dff86d9af
# 142                  NaN  862d718e091eca23d264d34dff86d9af
# 143                  NaN  2900eccbf740ae8de8fe49dd2b81e52d

# %% [markdown]
# ### Filter only necessary columns from Group D

# %%
standings[(standings['competition_structure_name'] == 'Group D')][['competition_structure_name','team_name_short','qualification_status','ranking','statistic_type','value']]
# each team has 9 statistic types that can be made into a subtable
# Out:
#     competition_structure_name team_name_short qualification_status  ranking  \
# 108                    Group D           Japan         CouldQualify        2
# 109                    Group D           Japan         CouldQualify        2
# 110                    Group D           Japan         CouldQualify        2
# 111                    Group D           Japan         CouldQualify        2
# 112                    Group D           Japan         CouldQualify        2
# 113                    Group D           Japan         CouldQualify        2
# 114                    Group D           Japan         CouldQualify        2
# 115                    Group D           Japan         CouldQualify        2
# 116                    Group D           Japan         CouldQualify        2
# 117                    Group D          Poland         CouldQualify        1
# 118                    Group D          Poland         CouldQualify        1
# 119                    Group D          Poland         CouldQualify        1
# 120                    Group D          Poland         CouldQualify        1
# 121                    Group D          Poland         CouldQualify        1
# 122                    Group D          Poland         CouldQualify        1
# 123                    Group D          Poland         CouldQualify        1
# 124                    Group D          Poland         CouldQualify        1
# 125                    Group D          Poland         CouldQualify        1
# 126                    Group D          Brazil         CouldQualify        3
# 127                    Group D          Brazil         CouldQualify        3
# 128                    Group D          Brazil         CouldQualify        3
# 129                    Group D          Brazil         CouldQualify        3
# 130                    Group D          Brazil         CouldQualify        3
# 131                    Group D          Brazil         CouldQualify        3
# 132                    Group D          Brazil         CouldQualify        3
# 133                    Group D          Brazil         CouldQualify        3
# 134                    Group D          Brazil         CouldQualify        3
# 135                    Group D          Zambia           Eliminated        4
# 136                    Group D          Zambia           Eliminated        4
# 137                    Group D          Zambia           Eliminated        4
# 138                    Group D          Zambia           Eliminated        4
# 139                    Group D          Zambia           Eliminated        4
# 140                    Group D          Zambia           Eliminated        4
# 141                    Group D          Zambia           Eliminated        4
# 142                    Group D          Zambia           Eliminated        4
# 143                    Group D          Zambia           Eliminated        4
#
#        statistic_type  value
# 108      GoalsAgainst      1
# 109   GoalsDifference      1
# 110          GoalsFor      2
# 111      MatchesDrawn      1
# 112       MatchesLost      0
# 113     MatchesPlayed      2
# 114        MatchesWon      1
# 115            Points      4
# 116  TeamConductScore     -1
# 117      GoalsAgainst      0
# 118   GoalsDifference      2
# 119          GoalsFor      2
# 120      MatchesDrawn      1
# 121       MatchesLost      0
# 122     MatchesPlayed      2
# 123        MatchesWon      1
# 124            Points      4
# 125  TeamConductScore     -1
# 126      GoalsAgainst      2
# 127   GoalsDifference      0
# 128          GoalsFor      2
# 129      MatchesDrawn      0
# 130       MatchesLost      1
# 131     MatchesPlayed      2
# 132        MatchesWon      1
# 133            Points      3
# 134  TeamConductScore     -4
# 135      GoalsAgainst      3
# 136   GoalsDifference     -3
# 137          GoalsFor      0
# 138      MatchesDrawn      0
# 139       MatchesLost      2
# 140     MatchesPlayed      2
# 141        MatchesWon      0
# 142            Points      0
# 143  TeamConductScore     -2

# %% [markdown]
# # Permutations

# %% [markdown]
# ### Encapsulate team data

# %%
japan = standings[
(standings['competition_structure_name'] == 'Group D') & (standings['team_name_short'] == 'Japan')][['competition_structure_name','team_name_short','qualification_status','ranking','statistic_type','value']]

poland = standings[
(standings['competition_structure_name'] == 'Group D') & (standings['team_name_short'] == 'Poland')][['competition_structure_name','team_name_short','qualification_status','ranking','statistic_type','value']]

brazil = standings[
(standings['competition_structure_name'] == 'Group D') & (standings['team_name_short'] == 'Brazil')][['competition_structure_name','team_name_short','qualification_status','ranking','statistic_type','value']]

zambia = standings[
(standings['competition_structure_name'] == 'Group D') & (standings['team_name_short'] == 'Zambia')][['competition_structure_name','team_name_short','qualification_status','ranking','statistic_type','value']]

# %% [markdown]
# ### Create dictionary for team stats and their values

# %%
japan_stats = japan.apply(lambda row: {row['statistic_type']: row['value']}, axis=1)
poland_stats = poland.apply(lambda row: {row['statistic_type']: row['value']}, axis=1)
brazil_stats = brazil.apply(lambda row: {row['statistic_type']: row['value']}, axis=1)
zambia_stats = zambia.apply(lambda row: {row['statistic_type']: row['value']}, axis=1)

japan_stats = {k: v for d in japan_stats for k, v in d.items()}
poland_stats = {k: v for d in poland_stats for k, v in d.items()}
brazil_stats = {k: v for d in brazil_stats for k, v in d.items()}
zambia_stats = {k: v for d in zambia_stats for k, v in d.items()}

#print(japan_stats)
#print(poland_stats)
#print(brazil_stats)
#print(zambia_stats)

# %%
teams = {
    'Japan': japan_stats,
    'Poland': poland_stats,
    'Brazil': brazil_stats
    #'Zambia': zambia_stats # ELIMINATED 
}

# define remaining games
total_group_games = 3
for team, stats in teams.items():
   stats['games_remaining'] = total_group_games - stats['MatchesPlayed']

# %% [markdown]
# ### Function to calculate outcome

# %%
def calculate_outcome_stats(outcome, team_stats):
    points = team_stats['Points']
    gd = team_stats['GoalsDifference']
    gf = team_stats['GoalsFor']
    ga = team_stats['GoalsAgainst']
    cs = team_stats['TeamConductScore']

    for result in outcome:
        if result == 'W':        # a win = add 3 points, increase GD, GF, CS
            points += 3
            gd += 2
            gf += 2
            cs += 1
        elif result == 'D':      # a draw = add 1 point, minimal GD, GF changes
            points += 1
            gd += 0
            gf += 1
        elif result == 'L':      # a loss = no points, decrease GD, no GF
            gd -= 1
            ga += 2
            cs -= 1

    return points, gd, gf, ga, cs

# %% [markdown]
# ### Apply permutations, calculate + logic

# %%
results = {}

for team, stats in teams.items():
    games_remaining = stats['games_remaining']
    outcomes = list(itertools.product(['W', 'D', 'L'], repeat=games_remaining))

    team_results = []
    for outcome in outcomes:
        points, gd, gf, ga, cs = calculate_outcome_stats(outcome, stats)
        team_results.append({
            'Outcome': outcome,
            'Points': points,
            'GoalsDifference': gd,
            'GoalsFor': gf,
            'GoalsAgainst': ga,
            'TeamConductScore': cs
        })

    # sort for each team based on P, GD, GF, and TCS
    sorted_results = sorted(team_results, key=lambda x: (x['Points'], x['GoalsDifference'], x['GoalsFor'], x['TeamConductScore']), reverse=True)
    results[team] = sorted_results

# display scenarios for each team
for team, scenarios in results.items():
    print(f"\n{team} Scenarios:")
    for scenario in scenarios:
        print(scenario)
# Out:
# Japan Scenarios:
# {'Outcome': ('W',), 'Points': 7, 'GoalsDifference': 3, 'GoalsFor': 4, 'GoalsAgainst': 1, 'TeamConductScore': 0}
# {'Outcome': ('D',), 'Points': 5, 'GoalsDifference': 1, 'GoalsFor': 3, 'GoalsAgainst': 1, 'TeamConductScore': -1}
# {'Outcome': ('L',), 'Points': 4, 'GoalsDifference': 0, 'GoalsFor': 2, 'GoalsAgainst': 3, 'TeamConductScore': -2}
#
# Poland Scenarios:
# {'Outcome': ('W',), 'Points': 7, 'GoalsDifference': 4, 'GoalsFor': 4, 'GoalsAgainst': 0, 'TeamConductScore': 0}
# {'Outcome': ('D',), 'Points': 5, 'GoalsDifference': 2, 'GoalsFor': 3, 'GoalsAgainst': 0, 'TeamConductScore': -1}
# {'Outcome': ('L',), 'Points': 4, 'GoalsDifference': 1, 'GoalsFor': 2, 'GoalsAgainst': 2, 'TeamConductScore': -2}
#
# Brazil Scenarios:
# {'Outcome': ('W',), 'Points': 6, 'GoalsDifference': 2, 'GoalsFor': 4, 'GoalsAgainst': 2, 'TeamConductScore': -3}
# {'Outcome': ('D',), 'Points': 4, 'GoalsDifference': 0, 'GoalsFor': 3, 'GoalsAgainst': 2, 'TeamConductScore': -4}
# {'Outcome': ('L',), 'Points': 3, 'GoalsDifference': -1, 'GoalsFor': 2, 'GoalsAgainst': 4, 'TeamConductScore': -5}

# %% [markdown]
# # Data Visualization

# %%
# flatten results for DataFrame conversion
scenarios_data = []
for team, scenarios in results.items():
    for scenario in scenarios:
        scenario_data = scenario.copy()  # copy to add team name
        scenario_data['Team'] = team
        scenarios_data.append(scenario_data)

# convert scenarios dict into DataFrame
df = pd.DataFrame(scenarios_data)

# generate Visualizations
# heatmap for Points by Team and Outcome
plt.figure(figsize=(10, 8))
heatmap_data = df.pivot_table(index='Outcome', columns='Team', values='Points', fill_value=0)
sns.heatmap(heatmap_data, annot=True, cmap='crest')
plt.title("Heatmap of Points by Outcome and Team")
plt.xlabel("Team")
plt.ylabel("Outcome")
plt.show()

# stacked Bar Chart for each team's outcomes with their statistics
for team, team_df in df.groupby('Team'):
    team_df.set_index('Outcome')[['Points', 'GoalsDifference', 'GoalsFor', 'GoalsAgainst']].plot(kind='bar', stacked=True, figsize=(10, 6))
    plt.title(f"Stacked Bar Chart of Points, GD, GF, GA for {team}")
    plt.ylabel("Value")
    plt.xlabel("Outcome")
    plt.show()
